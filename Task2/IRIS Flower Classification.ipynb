# %%
import pandas as pd
import numpy as np
import missingno as mso
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df= pd.read_csv("C:/Users/saroj/Documents/codsoft/Task2/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
mso.matrix(df,figsize=(10,5))

df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
num_col=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
cat_col=['species']

# %%
Le = LabelEncoder()
df['encoded_species'] = Le.fit_transform(df['species'])
print (df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      encoded_species
# 0                  0
# 1                  0
# ...

# %%
plt.figure(figsize=(17,6))
df['species'].value_counts().plot(kind='pie',autopct='%0.2f%%',ylabel='',title='Species')
# Out:
# <AxesSubplot: title={'center': 'Species'}>

# %%
# Calculate mean sepal length and sepal width for each species
mean_data = df.groupby('species').mean()

plt.figure(figsize=(10, 6))
sns.barplot(data=mean_data.reset_index(), x='species', y='sepal_length', palette='Set1')
plt.title('Mean Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Mean Sepal Length')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(data=mean_data.reset_index(), x='species', y='sepal_width', palette='Set2')
plt.title('Mean Sepal Width by Species')
plt.xlabel('Species')
plt.ylabel('Mean Sepal Width')
plt.show()

# %%
# Calculate mean sepal length and sepal width for each species
mean_data = df.groupby('species').mean()

plt.figure(figsize=(10, 6))
sns.barplot(data=mean_data.reset_index(), x='species', y='petal_length', palette='Set1')
plt.title('Mean Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Mean Sepal Length')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(data=mean_data.reset_index(), x='species', y='petal_width', palette='Set2')
plt.title('Mean Petal Width by Species')
plt.xlabel('Species')
plt.ylabel('Mean Petal Width')
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Create a FacetGrid for density distribution plots
g = sns.FacetGrid(df, aspect=1.5)
g.map(sns.kdeplot, 'sepal_length', color='blue', label='Sepal Length')
g.map(sns.kdeplot, 'sepal_width', color='green', label='Sepal Width')
g.map(sns.kdeplot, 'petal_length', color='purple', label='Petal Length')
g.map(sns.kdeplot, 'petal_width', color='orange', label='Petal Width')

# Adjust titles and labels
g.set_titles('Density Distribution of {col_name} Feature')
g.set_xlabels('Feature Values')
g.set_ylabels('Density')
g.add_legend()

# Adjust overall plot title and layout
plt.subplots_adjust(top=0.9)
plt.suptitle('Density Distribution of Iris Flower Features', fontsize=16)

plt.show()

# %%
le = LabelEncoder()
df['species']=le.fit_transform(df['species'])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  \
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
#      encoded_species
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# ...

# %%
from sklearn.model_selection import  train_test_split ,StratifiedKFold ,cross_val_score ,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X  = df.drop('species',axis=1)
y = df['species']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=42)

# %%
kfold = StratifiedKFold(n_splits=10)
random_state=42
clas = []
clas.append(LogisticRegression(random_state=random_state))
clas.append(DecisionTreeClassifier(random_state=random_state))
clas.append(RandomForestClassifier(random_state=random_state))
clas.append(GaussianNB())
clas.append(KNeighborsClassifier())
clas.append(SVC(random_state=random_state))

cv_result = []
for classi in clas:
    cv_result.append(cross_val_score(classi , X_train, y=y_train, scoring='accuracy',cv=kfold, n_jobs=4,))

cv_mean =[]
cv_std =[]
for result in cv_result:
    cv_mean.append(result.mean())
    cv_std.append(result.std())

cv = pd.DataFrame({'Cross_val_score':cv_mean, 'Cross_val_error':cv_std,'Algorithm':['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier', 'GaussianNB', 'KNeighborsClassifier', 'SVC']})

# %%
cv.sort_values(by='Cross_val_score',ascending=False)
# Out:
#    Cross_val_score  Cross_val_error               Algorithm
# 0              1.0              0.0      LogisticRegression
# 1              1.0              0.0  DecisionTreeClassifier
# 2              1.0              0.0  RandomForestClassifier
# 3              1.0              0.0              GaussianNB
# 4              1.0              0.0    KNeighborsClassifier
# 5              1.0              0.0                     SVC

# %%
LR = LogisticRegression()
LR.fit(X,y)
LR.score(X_test,y_test)
# Out:
# C:\Users\saroj\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1.0

# %%
DTC = DecisionTreeClassifier()
DTC.fit(X,y)
DTC.score(X_test,y_test)
# Out:
# 1.0

# %%
RFC = RandomForestClassifier()
param_grid = {
    'max_depth':[None,3,5,7],
    'min_samples_split':[2,3],
    'min_samples_leaf':[1,2],
    'random_state':[0]
}

grid_search= GridSearchCV(estimator=RFC,param_grid=param_grid,cv=5,n_jobs=5,verbose=3)
grid_search.fit(X_train,y_train)
RFC.fit(X,y)

grid_search.score(X_test,y_test)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# 1.0

# %%
ypred = LR.predict(X_test)
accuracy_score(y_test, ypred)
# Out:
# 1.0

# %%
report = classification_report(y_test, ypred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
import pickle

# %%
pickle.dump(LR, open('IRIS Flower Classification.pkl', 'wb'))
